# %%
import os
import torch
import torchvision
import torch.nn as nn
from torchvision import transforms
from torchvision.utils import save_image

# %%
# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Hyper-parameters
latent_size = 64
hidden_size = 256
image_size = 784
num_epochs = 200
batch_size = 100
sample_dir = 'gen_samples'

# Create a directory if not exists
if not os.path.exists(sample_dir):
    os.makedirs(sample_dir)

# %%
# Image processing
transform = transforms.Compose([
                transforms.ToTensor(),
                transforms.Normalize(mean=(0.5,),   # 3 for RGB channels
                                     std=(0.5,))])

# MNIST dataset
mnist = torchvision.datasets.MNIST(root='./data/',
                                   train=True,
                                   transform=transform,
                                   download=True)

# Data loader
data_loader = torch.utils.data.DataLoader(dataset=mnist,
                                          batch_size=batch_size, 
                                          shuffle=True)
# Out:
# 0it [00:00, ?it/s]
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to ./data/MNIST/raw/train-images-idx3-ubyte.gz
# 100%|█████████▉| 9871360/9912422 [00:46<00:00, 214244.23it/s]
# Extracting ./data/MNIST/raw/train-images-idx3-ubyte.gz to ./data/MNIST/raw
# 0it [00:00, ?it/s]
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to ./data/MNIST/raw/train-labels-idx1-ubyte.gz
#   0%|          | 0/28881 [00:00<?, ?it/s]
#  57%|█████▋    | 16384/28881 [00:00<00:00, 87407.45it/s]
# 32768it [00:00, 40563.69it/s]
# 0it [00:00, ?it/s]
# Extracting ./data/MNIST/raw/train-labels-idx1-ubyte.gz to ./data/MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to ./data/MNIST/raw/t10k-images-idx3-ubyte.gz
#   0%|          | 0/1648877 [00:00<?, ?it/s]
#   1%|          | 16384/1648877 [00:00<00:21, 75816.01it/s]
#   2%|▏         | 40960/1648877 [00:00<00:18, 86998.99it/s]
#   4%|▍         | 73728/1648877 [00:00<00:15, 102642.90it/s]
#   7%|▋         | 114688/1648877 [00:01<00:12, 122286.48it/s]
#   9%|▉         | 147456/1648877 [00:01<00:11, 134648.84it/s]
#  11%|█▏        | 188416/1648877 [00:01<00:09, 152477.60it/s]
#  14%|█▍        | 229376/1648877 [00:01<00:08, 168045.47it/s]
#  16%|█▋        | 270336/1648877 [00:01<00:07, 180935.82it/s]
#  19%|█▉        | 319488/1648877 [00:02<00:06, 199892.54it/s]
#  22%|██▏       | 360448/1648877 [00:02<00:06, 205665.79it/s]
#  25%|██▍       | 409600/1648877 [00:02<00:05, 220547.49it/s]
#  27%|██▋       | 442368/1648877 [00:02<00:05, 204036.73it/s]
#  30%|███       | 499712/1648877 [00:02<00:05, 228537.42it/s]
#  32%|███▏      | 532480/1648877 [00:03<00:05, 210355.83it/s]
#  35%|███▍      | 573440/1648877 [00:03<00:05, 213605.97it/s]
#  37%|███▋      | 614400/1648877 [00:03<00:04, 216023.59it/s]
#  40%|███▉      | 655360/1648877 [00:03<00:04, 217703.80it/s]
#  43%|████▎     | 704512/1648877 [00:03<00:04, 230281.35it/s]
#  46%|████▌     | 753664/1648877 [00:03<00:03, 239911.98it/s]
#  48%|████▊     | 794624/1648877 [00:04<00:03, 233997.51it/s]
#  52%|█████▏    | 851968/1648877 [00:04<00:03, 252692.31it/s]
#  55%|█████▍    | 901120/1648877 [00:04<00:02, 256624.66it/s]
#  58%|█████▊    | 950272/1648877 [00:04<00:02, 259378.55it/s]
#  61%|██████    | 999424/1648877 [00:04<00:02, 261346.58it/s]
#  64%|██████▍   | 1056768/1648877 [00:05<00:02, 274381.18it/s]
#  67%|██████▋   | 1105920/1648877 [00:05<00:01, 271837.34it/s]
#  70%|███████   | 1155072/1648877 [00:05<00:01, 270070.74it/s]
#  74%|███████▎  | 1212416/1648877 [00:05<00:01, 280987.02it/s]
#  76%|███████▌  | 1245184/1648877 [00:05<00:01, 234750.65it/s]
#  79%|███████▉  | 1302528/1648877 [00:05<00:01, 256567.05it/s]
#  81%|████████  | 1335296/1648877 [00:06<00:01, 226157.20it/s]
#  83%|████████▎ | 1376256/1648877 [00:06<00:01, 224839.57it/s]
#  86%|████████▌ | 1417216/1648877 [00:06<00:01, 223916.17it/s]
#  88%|████████▊ | 1458176/1648877 [00:06<00:00, 223252.87it/s]
#  91%|█████████▏| 1507328/1648877 [00:06<00:00, 234575.23it/s]
#  94%|█████████▍| 1556480/1648877 [00:07<00:00, 243152.20it/s]
#  97%|█████████▋| 1605632/1648877 [00:07<00:00, 249646.42it/s]
#
# 0it [00:00, ?it/s]
# Extracting ./data/MNIST/raw/t10k-images-idx3-ubyte.gz to ./data/MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to ./data/MNIST/raw/t10k-labels-idx1-ubyte.gz
#   0%|          | 0/4542 [00:00<?, ?it/s]
#
# 8192it [00:00, 21678.38it/s]
# Extracting ./data/MNIST/raw/t10k-labels-idx1-ubyte.gz to ./data/MNIST/raw
# Processing...
# Done!

# %%
# Discriminator
# The output of D is no longer a probability, we do not apply sigmoid at the output of D.
wD = nn.Sequential(
    nn.Linear(image_size, hidden_size),
    nn.LeakyReLU(0.2),
    nn.Linear(hidden_size, hidden_size),
    nn.LeakyReLU(0.2),
    nn.Linear(hidden_size, 1)
    )

# Generator 
wG = nn.Sequential(
    nn.Linear(latent_size, hidden_size),
    nn.ReLU(),
    nn.Linear(hidden_size, hidden_size),
    nn.ReLU(),
    nn.Linear(hidden_size, image_size),
    nn.Tanh())

# Device setting
wD = wD.to(device)
wG = wG.to(device)

# Wasserstein distance loss and WGAN values from paper
weight_cliping_limit = 0.01
critic_iter = 5

# WGAN with gradient clipping uses RMSprop instead of ADAM
wg_optimizer = torch.optim.RMSprop(wG.parameters(), lr=0.00005)
wd_optimizer = torch.optim.RMSprop(wD.parameters(), lr=0.00005)

def denorm(x):
    out = (x + 1) / 2
    return out.clamp(0, 1)

# %%
def get_infinite_batches(data_loader):
    while True:
        for i, (images, _) in enumerate(data_loader):
            yield images

# %%
# Start training
total_step = 600*200
data = get_infinite_batches(data_loader)
for currstep in range(total_step):        
    
    # ================================================================== #
    #                      Train the discriminator                       #
    # ================================================================== #
    
    # Requires grad
    for p in wD.parameters():
        p.requires_grad = True
    
    for d_iter in range(critic_iter):    
        wd_optimizer.zero_grad()   
            
        images = data.__next__().to(device)
        images = images.reshape(batch_size, -1).to(device)
    
        # Train with real images
        outputs = wD(images)
        wd_loss_real = outputs.mean(0).view(1)
        
        # Train with fake images        
        z = torch.randn(batch_size, latent_size).to(device)
        fake_images = wG(z)
        outputs = wD(fake_images)
        wd_loss_fake = outputs.mean(0).view(1)
        
        # For displaying the trends
        wd_loss = wd_loss_fake - wd_loss_real
        wd_loss.backward()
        Wasserstein_D = wd_loss_real - wd_loss_fake
        
        # Backprop and optimize             
        wd_optimizer.step()

        # Clamp parameters to a range [-c, c], c=weight_cliping_limit
        for p in wD.parameters():
            p.data.clamp_(-weight_cliping_limit, weight_cliping_limit)
            
    # ================================================================== #
    #                        Train the generator                         #
    # ================================================================== #

    for p in wD.parameters():
        p.requires_grad = False  # to avoid computation

    # Compute loss with fake images
    z = torch.randn(batch_size, latent_size).to(device)
    fake_images = wG(z)
    outputs = wD(fake_images)
    wg_loss = -outputs.mean().mean(0).view(1)        
    wg_optimizer.zero_grad()    
    wg_loss.backward()
    
    # Backprop and optimize            
    wg_optimizer.step()

    if (currstep+1) % 200 == 0:
        print('Curr_step [{}/{}], wd_loss: {:.4f}, wg_loss: {:.4f}, D(x): {:.2f}, D(G(z)): {:.2f}' 
              .format(currstep+1, total_step, wd_loss.item(), -wg_loss.item(), 
                      wd_loss_real.item(), wd_loss_fake.item()))
    if (currstep+1) % 600 == 0:
        epoch = (currstep+1) // 600
        # Save sampled images
        fake_images = fake_images.reshape(fake_images.size(0), 1, 28, 28)
        save_image(denorm(fake_images), os.path.join(sample_dir, 'wgan_fake_images-{}.png'.format(epoch)))
        print('Saved generated images..!')

    # Save real images
    if (currstep+1) == 1:
        images = images.reshape(images.size(0), 1, 28, 28)
        save_image(denorm(images), os.path.join(sample_dir, 'real_images.png'))
        print('Saved real images..!')
    

# Save the model checkpoints 
torch.save(wG.state_dict(), 'wG.ckpt')
torch.save(wD.state_dict(), 'wD.ckpt')
# Out:
# Saved real images..!
# 1654784it [00:22, 249646.42it/s]
# Curr_step [200/120000], wd_loss: -0.0877, wg_loss: 6.2192, D(x): 6.32, D(G(z)): 6.23
# Curr_step [400/120000], wd_loss: 0.0014, wg_loss: 4.2816, D(x): 4.29, D(G(z)): 4.29
# Curr_step [600/120000], wd_loss: -0.1408, wg_loss: 1.3731, D(x): 1.49, D(G(z)): 1.35
# Saved generated images..!
# Curr_step [800/120000], wd_loss: -0.2073, wg_loss: 2.1858, D(x): 2.39, D(G(z)): 2.18
# Curr_step [1000/120000], wd_loss: -0.2183, wg_loss: 1.9515, D(x): 2.19, D(G(z)): 1.97
# Curr_step [1200/120000], wd_loss: -0.1442, wg_loss: 1.6466, D(x): 1.79, D(G(z)): 1.65
# Saved generated images..!
# Curr_step [1400/120000], wd_loss: -0.1834, wg_loss: 1.0261, D(x): 1.22, D(G(z)): 1.03
# Curr_step [1600/120000], wd_loss: -0.1572, wg_loss: 0.7849, D(x): 0.95, D(G(z)): 0.80
# Curr_step [1800/120000], wd_loss: -0.2074, wg_loss: 0.8336, D(x): 1.03, D(G(z)): 0.83
# Saved generated images..!
# Curr_step [2000/120000], wd_loss: -0.1764, wg_loss: 0.8617, D(x): 1.04, D(G(z)): 0.87
# Curr_step [2200/120000], wd_loss: -0.1797, wg_loss: 0.7067, D(x): 0.90, D(G(z)): 0.72
# Curr_step [2400/120000], wd_loss: -0.1680, wg_loss: 0.5147, D(x): 0.68, D(G(z)): 0.52
# Saved generated images..!
# Curr_step [2600/120000], wd_loss: -0.1765, wg_loss: 0.4453, D(x): 0.62, D(G(z)): 0.44
# Curr_step [2800/120000], wd_loss: -0.1518, wg_loss: 0.4399, D(x): 0.59, D(G(z)): 0.44
# Curr_step [3000/120000], wd_loss: -0.0959, wg_loss: 0.6554, D(x): 0.73, D(G(z)): 0.63
# Saved generated images..!
# Curr_step [3200/120000], wd_loss: -0.1427, wg_loss: 0.5024, D(x): 0.64, D(G(z)): 0.49
# Curr_step [3400/120000], wd_loss: -0.1271, wg_loss: 0.3995, D(x): 0.53, D(G(z)): 0.40
# Curr_step [3600/120000], wd_loss: -0.1246, wg_loss: 0.4761, D(x): 0.60, D(G(z)): 0.48
# Saved generated images..!
# Curr_step [3800/120000], wd_loss: -0.1154, wg_loss: 0.3334, D(x): 0.46, D(G(z)): 0.35
# Curr_step [4000/120000], wd_loss: -0.1333, wg_loss: 0.2226, D(x): 0.37, D(G(z)): 0.24
# Curr_step [4200/120000], wd_loss: -0.1282, wg_loss: 0.2196, D(x): 0.35, D(G(z)): 0.22
# Saved generated images..!
# Curr_step [4400/120000], wd_loss: -0.1402, wg_loss: 0.2577, D(x): 0.40, D(G(z)): 0.26
# Curr_step [4600/120000], wd_loss: -0.1281, wg_loss: 0.1612, D(x): 0.29, D(G(z)): 0.16
# Curr_step [4800/120000], wd_loss: -0.1372, wg_loss: 0.2023, D(x): 0.34, D(G(z)): 0.20
# Saved generated images..!
# Curr_step [5000/120000], wd_loss: -0.1192, wg_loss: 0.1902, D(x): 0.31, D(G(z)): 0.19
# Curr_step [5200/120000], wd_loss: -0.1187, wg_loss: 0.2460, D(x): 0.35, D(G(z)): 0.23
# Curr_step [5400/120000], wd_loss: -0.1229, wg_loss: 0.2091, D(x): 0.34, D(G(z)): 0.22
# Saved generated images..!
# Curr_step [5600/120000], wd_loss: -0.2247, wg_loss: 0.3852, D(x): 0.60, D(G(z)): 0.38
# Curr_step [5800/120000], wd_loss: -0.2051, wg_loss: 0.2222, D(x): 0.41, D(G(z)): 0.20
# Curr_step [6000/120000], wd_loss: -0.2162, wg_loss: 0.2256, D(x): 0.44, D(G(z)): 0.22
# Saved generated images..!
# Curr_step [6200/120000], wd_loss: -0.2121, wg_loss: 0.2840, D(x): 0.50, D(G(z)): 0.29
# Curr_step [6400/120000], wd_loss: -0.2179, wg_loss: 0.3894, D(x): 0.63, D(G(z)): 0.41
# Curr_step [6600/120000], wd_loss: -0.1847, wg_loss: 0.1215, D(x): 0.32, D(G(z)): 0.14
# Saved generated images..!
# Curr_step [6800/120000], wd_loss: -0.2028, wg_loss: 0.3639, D(x): 0.57, D(G(z)): 0.37
# Curr_step [7000/120000], wd_loss: -0.1908, wg_loss: 0.2524, D(x): 0.45, D(G(z)): 0.26
# Curr_step [7200/120000], wd_loss: -0.1837, wg_loss: 0.2132, D(x): 0.42, D(G(z)): 0.23
# Saved generated images..!
# Curr_step [7400/120000], wd_loss: -0.1666, wg_loss: 0.2405, D(x): 0.38, D(G(z)): 0.22
# Curr_step [7600/120000], wd_loss: -0.1684, wg_loss: 0.3210, D(x): 0.49, D(G(z)): 0.32
# Curr_step [7800/120000], wd_loss: -0.1932, wg_loss: 0.1287, D(x): 0.32, D(G(z)): 0.13
# Saved generated images..!
# Curr_step [8000/120000], wd_loss: -0.1801, wg_loss: 0.4477, D(x): 0.61, D(G(z)): 0.43
# Curr_step [8200/120000], wd_loss: -0.1809, wg_loss: 0.3331, D(x): 0.53, D(G(z)): 0.35
# Curr_step [8400/120000], wd_loss: -0.1595, wg_loss: 0.4726, D(x): 0.62, D(G(z)): 0.46
# Saved generated images..!
# Curr_step [8600/120000], wd_loss: -0.1552, wg_loss: 0.4659, D(x): 0.58, D(G(z)): 0.42
# Curr_step [8800/120000], wd_loss: -0.1527, wg_loss: 0.2869, D(x): 0.46, D(G(z)): 0.30
# Curr_step [9000/120000], wd_loss: -0.1447, wg_loss: 0.3326, D(x): 0.49, D(G(z)): 0.35
# Saved generated images..!
# Curr_step [9200/120000], wd_loss: -0.1493, wg_loss: 0.3649, D(x): 0.53, D(G(z)): 0.38
# Curr_step [9400/120000], wd_loss: -0.1602, wg_loss: 0.2642, D(x): 0.43, D(G(z)): 0.27
# Curr_step [9600/120000], wd_loss: -0.1486, wg_loss: 0.3033, D(x): 0.45, D(G(z)): 0.30
# Saved generated images..!
# Curr_step [9800/120000], wd_loss: -0.1402, wg_loss: 0.2879, D(x): 0.42, D(G(z)): 0.28
# Curr_step [10000/120000], wd_loss: -0.1402, wg_loss: 0.3105, D(x): 0.45, D(G(z)): 0.31
# Curr_step [10200/120000], wd_loss: -0.1290, wg_loss: 0.1145, D(x): 0.26, D(G(z)): 0.13
# Saved generated images..!
# Curr_step [10400/120000], wd_loss: -0.1270, wg_loss: 0.2578, D(x): 0.38, D(G(z)): 0.26
# Curr_step [10600/120000], wd_loss: -0.1323, wg_loss: 0.1907, D(x): 0.33, D(G(z)): 0.20
# Curr_step [10800/120000], wd_loss: -0.1427, wg_loss: 0.2666, D(x): 0.41, D(G(z)): 0.27
# Saved generated images..!
# Curr_step [11000/120000], wd_loss: -0.1273, wg_loss: 0.2321, D(x): 0.37, D(G(z)): 0.24
# Curr_step [11200/120000], wd_loss: -0.1423, wg_loss: 0.2764, D(x): 0.42, D(G(z)): 0.27
# Curr_step [11400/120000], wd_loss: -0.1233, wg_loss: 0.2072, D(x): 0.32, D(G(z)): 0.20
# Saved generated images..!
# Curr_step [11600/120000], wd_loss: -0.1336, wg_loss: 0.1709, D(x): 0.31, D(G(z)): 0.17
# Curr_step [11800/120000], wd_loss: -0.1354, wg_loss: 0.2415, D(x): 0.37, D(G(z)): 0.23
# Curr_step [12000/120000], wd_loss: -0.1216, wg_loss: 0.0098, D(x): 0.14, D(G(z)): 0.02
# Saved generated images..!
# Curr_step [12200/120000], wd_loss: -0.1234, wg_loss: 0.2471, D(x): 0.37, D(G(z)): 0.24
# Curr_step [12400/120000], wd_loss: -0.1100, wg_loss: 0.2541, D(x): 0.35, D(G(z)): 0.24
# Curr_step [12600/120000], wd_loss: -0.1312, wg_loss: 0.1865, D(x): 0.32, D(G(z)): 0.19
# Saved generated images..!
# Curr_step [12800/120000], wd_loss: -0.1097, wg_loss: 0.1999, D(x): 0.30, D(G(z)): 0.19
# Curr_step [13000/120000], wd_loss: -0.1232, wg_loss: 0.1473, D(x): 0.27, D(G(z)): 0.15
# Curr_step [13200/120000], wd_loss: -0.1123, wg_loss: 0.1723, D(x): 0.29, D(G(z)): 0.18
# Saved generated images..!
# Curr_step [13400/120000], wd_loss: -0.1095, wg_loss: 0.2120, D(x): 0.31, D(G(z)): 0.20
# Curr_step [13600/120000], wd_loss: -0.1193, wg_loss: 0.1505, D(x): 0.26, D(G(z)): 0.14
# Curr_step [13800/120000], wd_loss: -0.1187, wg_loss: 0.1360, D(x): 0.25, D(G(z)): 0.13
# Saved generated images..!
# Curr_step [14000/120000], wd_loss: -0.1133, wg_loss: 0.1205, D(x): 0.24, D(G(z)): 0.13
# Curr_step [14200/120000], wd_loss: -0.0971, wg_loss: 0.2096, D(x): 0.30, D(G(z)): 0.20
# Curr_step [14400/120000], wd_loss: -0.1093, wg_loss: 0.1926, D(x): 0.30, D(G(z)): 0.19
# Saved generated images..!
# Curr_step [14600/120000], wd_loss: -0.1018, wg_loss: 0.1415, D(x): 0.24, D(G(z)): 0.14
# Curr_step [14800/120000], wd_loss: -0.1249, wg_loss: 0.1923, D(x): 0.31, D(G(z)): 0.18
# Curr_step [15000/120000], wd_loss: -0.1222, wg_loss: 0.1571, D(x): 0.28, D(G(z)): 0.15
# Saved generated images..!
# Curr_step [15200/120000], wd_loss: -0.1040, wg_loss: 0.1328, D(x): 0.24, D(G(z)): 0.13
# Curr_step [15400/120000], wd_loss: -0.1069, wg_loss: 0.2041, D(x): 0.29, D(G(z)): 0.19
# Curr_step [15600/120000], wd_loss: -0.1072, wg_loss: 0.1604, D(x): 0.27, D(G(z)): 0.16
# Saved generated images..!
# Curr_step [15800/120000], wd_loss: -0.1026, wg_loss: 0.1332, D(x): 0.25, D(G(z)): 0.15
# Curr_step [16000/120000], wd_loss: -0.0881, wg_loss: 0.1104, D(x): 0.21, D(G(z)): 0.12
# Curr_step [16200/120000], wd_loss: -0.0949, wg_loss: 0.1450, D(x): 0.24, D(G(z)): 0.15
# Saved generated images..!
# Curr_step [16400/120000], wd_loss: -0.1125, wg_loss: 0.1787, D(x): 0.28, D(G(z)): 0.17
# Curr_step [16600/120000], wd_loss: -0.0928, wg_loss: 0.1184, D(x): 0.23, D(G(z)): 0.13
# Curr_step [16800/120000], wd_loss: -0.0977, wg_loss: 0.1885, D(x): 0.29, D(G(z)): 0.19
# Saved generated images..!
# Curr_step [17000/120000], wd_loss: -0.1051, wg_loss: 0.1530, D(x): 0.27, D(G(z)): 0.16
# Curr_step [17200/120000], wd_loss: -0.0958, wg_loss: 0.1360, D(x): 0.23, D(G(z)): 0.13
# Curr_step [17400/120000], wd_loss: -0.0890, wg_loss: 0.1593, D(x): 0.25, D(G(z)): 0.16
# Saved generated images..!
# Curr_step [17600/120000], wd_loss: -0.0929, wg_loss: 0.1189, D(x): 0.19, D(G(z)): 0.09
# Curr_step [17800/120000], wd_loss: -0.0957, wg_loss: 0.1048, D(x): 0.22, D(G(z)): 0.12
# Curr_step [18000/120000], wd_loss: -0.0975, wg_loss: 0.0765, D(x): 0.19, D(G(z)): 0.09
# Saved generated images..!
# Curr_step [18200/120000], wd_loss: -0.1088, wg_loss: 0.0724, D(x): 0.19, D(G(z)): 0.08
# Curr_step [18400/120000], wd_loss: -0.1204, wg_loss: 0.0489, D(x): 0.17, D(G(z)): 0.05
# Curr_step [18600/120000], wd_loss: -0.1036, wg_loss: 0.0463, D(x): 0.15, D(G(z)): 0.04
# Saved generated images..!
# Curr_step [18800/120000], wd_loss: -0.1065, wg_loss: 0.0347, D(x): 0.14, D(G(z)): 0.03
# Curr_step [19000/120000], wd_loss: -0.0984, wg_loss: 0.0106, D(x): 0.10, D(G(z)): 0.00
# Curr_step [19200/120000], wd_loss: -0.1059, wg_loss: 0.0478, D(x): 0.16, D(G(z)): 0.06
# Saved generated images..!
# Curr_step [19400/120000], wd_loss: -0.0847, wg_loss: 0.0070, D(x): 0.09, D(G(z)): 0.01
# Curr_step [19600/120000], wd_loss: -0.1013, wg_loss: 0.0233, D(x): 0.14, D(G(z)): 0.04
# Curr_step [19800/120000], wd_loss: -0.1115, wg_loss: -0.0142, D(x): 0.10, D(G(z)): -0.01
# Saved generated images..!
# Curr_step [20000/120000], wd_loss: -0.0928, wg_loss: -0.0112, D(x): 0.10, D(G(z)): 0.01
# Curr_step [20200/120000], wd_loss: -0.1007, wg_loss: -0.0158, D(x): 0.07, D(G(z)): -0.03
# Curr_step [20400/120000], wd_loss: -0.1061, wg_loss: -0.0018, D(x): 0.10, D(G(z)): -0.01
# Saved generated images..!
# Curr_step [20600/120000], wd_loss: -0.0924, wg_loss: 0.0126, D(x): 0.11, D(G(z)): 0.02
# Curr_step [20800/120000], wd_loss: -0.1035, wg_loss: -0.0372, D(x): 0.08, D(G(z)): -0.03
# Curr_step [21000/120000], wd_loss: -0.1046, wg_loss: 0.0259, D(x): 0.12, D(G(z)): 0.01
# Saved generated images..!
# Curr_step [21200/120000], wd_loss: -0.0944, wg_loss: 0.0293, D(x): 0.13, D(G(z)): 0.04
# Curr_step [21400/120000], wd_loss: -0.0994, wg_loss: 0.0074, D(x): 0.10, D(G(z)): 0.00
# Curr_step [21600/120000], wd_loss: -0.1056, wg_loss: -0.0027, D(x): 0.11, D(G(z)): 0.00
# Saved generated images..!
# Curr_step [21800/120000], wd_loss: -0.0951, wg_loss: -0.0061, D(x): 0.09, D(G(z)): -0.01
# Curr_step [22000/120000], wd_loss: -0.0927, wg_loss: 0.0130, D(x): 0.12, D(G(z)): 0.03
# Curr_step [22200/120000], wd_loss: -0.0934, wg_loss: 0.0235, D(x): 0.14, D(G(z)): 0.04
# Saved generated images..!
# Curr_step [22400/120000], wd_loss: -0.0936, wg_loss: 0.0117, D(x): 0.10, D(G(z)): 0.00
# Curr_step [22600/120000], wd_loss: -0.1104, wg_loss: 0.0477, D(x): 0.16, D(G(z)): 0.05
# Curr_step [22800/120000], wd_loss: -0.0910, wg_loss: 0.0287, D(x): 0.13, D(G(z)): 0.04
# Saved generated images..!
# Curr_step [23000/120000], wd_loss: -0.0818, wg_loss: -0.0137, D(x): 0.09, D(G(z)): 0.01
# Curr_step [23200/120000], wd_loss: -0.0862, wg_loss: 0.0277, D(x): 0.11, D(G(z)): 0.02
# Curr_step [23400/120000], wd_loss: -0.0990, wg_loss: 0.0308, D(x): 0.13, D(G(z)): 0.03
# Saved generated images..!
# Curr_step [23600/120000], wd_loss: -0.0811, wg_loss: 0.0200, D(x): 0.09, D(G(z)): 0.00
# Curr_step [23800/120000], wd_loss: -0.0785, wg_loss: 0.0281, D(x): 0.11, D(G(z)): 0.03
# Curr_step [24000/120000], wd_loss: -0.0916, wg_loss: 0.0110, D(x): 0.12, D(G(z)): 0.03
# Saved generated images..!
# Curr_step [24200/120000], wd_loss: -0.0875, wg_loss: 0.0041, D(x): 0.11, D(G(z)): 0.02
# Curr_step [24400/120000], wd_loss: -0.0751, wg_loss: 0.0097, D(x): 0.08, D(G(z)): 0.01
# Curr_step [24600/120000], wd_loss: -0.0918, wg_loss: -0.0052, D(x): 0.08, D(G(z)): -0.01
# Saved generated images..!
# Curr_step [24800/120000], wd_loss: -0.0686, wg_loss: 0.0213, D(x): 0.08, D(G(z)): 0.01
# Curr_step [25000/120000], wd_loss: -0.0745, wg_loss: 0.0049, D(x): 0.08, D(G(z)): 0.01
# Curr_step [25200/120000], wd_loss: -0.0799, wg_loss: 0.0183, D(x): 0.07, D(G(z)): -0.01
# Saved generated images..!
# Curr_step [25400/120000], wd_loss: -0.0746, wg_loss: 0.0055, D(x): 0.08, D(G(z)): 0.01
# Curr_step [25600/120000], wd_loss: -0.0804, wg_loss: 0.0060, D(x): 0.09, D(G(z)): 0.01
# Curr_step [25800/120000], wd_loss: -0.0787, wg_loss: 0.0035, D(x): 0.08, D(G(z)): 0.00
# Saved generated images..!
# Curr_step [26000/120000], wd_loss: -0.0782, wg_loss: -0.0038, D(x): 0.08, D(G(z)): 0.00
# Curr_step [26200/120000], wd_loss: -0.0755, wg_loss: 0.0440, D(x): 0.13, D(G(z)): 0.06
# Curr_step [26400/120000], wd_loss: -0.0714, wg_loss: -0.0075, D(x): 0.08, D(G(z)): 0.01
# Saved generated images..!
# Curr_step [26600/120000], wd_loss: -0.0810, wg_loss: -0.0303, D(x): 0.04, D(G(z)): -0.04
# Curr_step [26800/120000], wd_loss: -0.0809, wg_loss: 0.0059, D(x): 0.07, D(G(z)): -0.01
# Curr_step [27000/120000], wd_loss: -0.0771, wg_loss: -0.0120, D(x): 0.07, D(G(z)): -0.01
# Saved generated images..!
# Curr_step [27200/120000], wd_loss: -0.0709, wg_loss: 0.0041, D(x): 0.10, D(G(z)): 0.03
# Curr_step [27400/120000], wd_loss: -0.0783, wg_loss: -0.0031, D(x): 0.06, D(G(z)): -0.02
# Curr_step [27600/120000], wd_loss: -0.0802, wg_loss: 0.0249, D(x): 0.09, D(G(z)): 0.01
# Saved generated images..!
# Curr_step [27800/120000], wd_loss: -0.0698, wg_loss: 0.0291, D(x): 0.12, D(G(z)): 0.05
# Curr_step [28000/120000], wd_loss: -0.0761, wg_loss: -0.0093, D(x): 0.07, D(G(z)): -0.00
# Curr_step [28200/120000], wd_loss: -0.0671, wg_loss: -0.0205, D(x): 0.05, D(G(z)): -0.02
# Saved generated images..!
# Curr_step [28400/120000], wd_loss: -0.0714, wg_loss: 0.0180, D(x): 0.08, D(G(z)): 0.01
# Curr_step [28600/120000], wd_loss: -0.0697, wg_loss: 0.0230, D(x): 0.09, D(G(z)): 0.02
# Curr_step [28800/120000], wd_loss: -0.0665, wg_loss: -0.0202, D(x): 0.04, D(G(z)): -0.03
# Saved generated images..!
# Curr_step [29000/120000], wd_loss: -0.0695, wg_loss: 0.0074, D(x): 0.09, D(G(z)): 0.02
# Curr_step [29200/120000], wd_loss: -0.0703, wg_loss: 0.0158, D(x): 0.08, D(G(z)): 0.01
# Curr_step [29400/120000], wd_loss: -0.0660, wg_loss: -0.0045, D(x): 0.05, D(G(z)): -0.02
# Saved generated images..!
# Curr_step [29600/120000], wd_loss: -0.0604, wg_loss: -0.0342, D(x): 0.02, D(G(z)): -0.04
# Curr_step [29800/120000], wd_loss: -0.0643, wg_loss: 0.0140, D(x): 0.07, D(G(z)): 0.01
# Curr_step [30000/120000], wd_loss: -0.0776, wg_loss: -0.0115, D(x): 0.07, D(G(z)): -0.00
# Saved generated images..!
# Curr_step [30200/120000], wd_loss: -0.0615, wg_loss: -0.0071, D(x): 0.06, D(G(z)): -0.00
# Curr_step [30400/120000], wd_loss: -0.0761, wg_loss: 0.0401, D(x): 0.10, D(G(z)): 0.02
# Curr_step [30600/120000], wd_loss: -0.0687, wg_loss: 0.0287, D(x): 0.12, D(G(z)): 0.05
# Saved generated images..!
# Curr_step [30800/120000], wd_loss: -0.0811, wg_loss: 0.0064, D(x): 0.09, D(G(z)): 0.01
# Curr_step [31000/120000], wd_loss: -0.0593, wg_loss: 0.0047, D(x): 0.07, D(G(z)): 0.01
# Curr_step [31200/120000], wd_loss: -0.0746, wg_loss: 0.0244, D(x): 0.08, D(G(z)): 0.00
# Saved generated images..!
# Curr_step [31400/120000], wd_loss: -0.0622, wg_loss: -0.0339, D(x): 0.04, D(G(z)): -0.02
# Curr_step [31600/120000], wd_loss: -0.0564, wg_loss: 0.0121, D(x): 0.07, D(G(z)): 0.01
# Curr_step [31800/120000], wd_loss: -0.0660, wg_loss: 0.0059, D(x): 0.08, D(G(z)): 0.01
# Saved generated images..!
# Curr_step [32000/120000], wd_loss: -0.0713, wg_loss: 0.0394, D(x): 0.12, D(G(z)): 0.05
# Curr_step [32200/120000], wd_loss: -0.0608, wg_loss: 0.0301, D(x): 0.09, D(G(z)): 0.03
# Curr_step [32400/120000], wd_loss: -0.0674, wg_loss: 0.0173, D(x): 0.08, D(G(z)): 0.01
# Saved generated images..!
# Curr_step [32600/120000], wd_loss: -0.0721, wg_loss: 0.0475, D(x): 0.11, D(G(z)): 0.04
# Curr_step [32800/120000], wd_loss: -0.0621, wg_loss: 0.0537, D(x): 0.11, D(G(z)): 0.04
# Curr_step [33000/120000], wd_loss: -0.0571, wg_loss: -0.0097, D(x): 0.04, D(G(z)): -0.02
# Saved generated images..!
# Curr_step [33200/120000], wd_loss: -0.0726, wg_loss: 0.0892, D(x): 0.14, D(G(z)): 0.06
# Curr_step [33400/120000], wd_loss: -0.0666, wg_loss: 0.0006, D(x): 0.05, D(G(z)): -0.02
# Curr_step [33600/120000], wd_loss: -0.0487, wg_loss: 0.0520, D(x): 0.12, D(G(z)): 0.07
# Saved generated images..!
# Curr_step [33800/120000], wd_loss: -0.0685, wg_loss: 0.0025, D(x): 0.08, D(G(z)): 0.02
# Curr_step [34000/120000], wd_loss: -0.0678, wg_loss: 0.0038, D(x): 0.07, D(G(z)): 0.00
# Curr_step [34200/120000], wd_loss: -0.0611, wg_loss: 0.0228, D(x): 0.10, D(G(z)): 0.04
# Saved generated images..!
# Curr_step [34400/120000], wd_loss: -0.0734, wg_loss: 0.0067, D(x): 0.07, D(G(z)): -0.00
# Curr_step [34600/120000], wd_loss: -0.0642, wg_loss: 0.0365, D(x): 0.08, D(G(z)): 0.02
# Curr_step [34800/120000], wd_loss: -0.0543, wg_loss: -0.0303, D(x): 0.02, D(G(z)): -0.03
# Saved generated images..!
# Curr_step [35000/120000], wd_loss: -0.0563, wg_loss: 0.0344, D(x): 0.11, D(G(z)): 0.05
# Curr_step [35200/120000], wd_loss: -0.0558, wg_loss: 0.0053, D(x): 0.06, D(G(z)): 0.01
# Curr_step [35400/120000], wd_loss: -0.0612, wg_loss: -0.0281, D(x): 0.04, D(G(z)): -0.02
# Saved generated images..!
# Curr_step [35600/120000], wd_loss: -0.0779, wg_loss: 0.0260, D(x): 0.08, D(G(z)): 0.00
# Curr_step [35800/120000], wd_loss: -0.0642, wg_loss: 0.0208, D(x): 0.07, D(G(z)): 0.00
# Curr_step [36000/120000], wd_loss: -0.0579, wg_loss: 0.0043, D(x): 0.08, D(G(z)): 0.02
# Saved generated images..!
# Curr_step [36200/120000], wd_loss: -0.0607, wg_loss: 0.0220, D(x): 0.07, D(G(z)): 0.01
# Curr_step [36400/120000], wd_loss: -0.0497, wg_loss: -0.0220, D(x): 0.04, D(G(z)): -0.01
# Curr_step [36600/120000], wd_loss: -0.0612, wg_loss: -0.0190, D(x): 0.05, D(G(z)): -0.01
# Saved generated images..!
# Curr_step [36800/120000], wd_loss: -0.0719, wg_loss: 0.0245, D(x): 0.10, D(G(z)): 0.02
# Curr_step [37000/120000], wd_loss: -0.0557, wg_loss: 0.0058, D(x): 0.06, D(G(z)): 0.00
# Curr_step [37200/120000], wd_loss: -0.0639, wg_loss: 0.0171, D(x): 0.08, D(G(z)): 0.01
# Saved generated images..!
# Curr_step [37400/120000], wd_loss: -0.0450, wg_loss: -0.0594, D(x): -0.01, D(G(z)): -0.05
# Curr_step [37600/120000], wd_loss: -0.0665, wg_loss: -0.0120, D(x): 0.03, D(G(z)): -0.04
# Curr_step [37800/120000], wd_loss: -0.0674, wg_loss: -0.0302, D(x): 0.04, D(G(z)): -0.03
# Saved generated images..!
# Curr_step [38000/120000], wd_loss: -0.0531, wg_loss: -0.0152, D(x): 0.04, D(G(z)): -0.01
# Curr_step [38200/120000], wd_loss: -0.0593, wg_loss: -0.0133, D(x): 0.04, D(G(z)): -0.02
# Curr_step [38400/120000], wd_loss: -0.0499, wg_loss: -0.0231, D(x): 0.03, D(G(z)): -0.02
# Saved generated images..!
# Curr_step [38600/120000], wd_loss: -0.0616, wg_loss: -0.0457, D(x): 0.02, D(G(z)): -0.04
# Curr_step [38800/120000], wd_loss: -0.0615, wg_loss: 0.0224, D(x): 0.08, D(G(z)): 0.02
# Curr_step [39000/120000], wd_loss: -0.0578, wg_loss: -0.0409, D(x): 0.02, D(G(z)): -0.03
# Saved generated images..!
# Curr_step [39200/120000], wd_loss: -0.0614, wg_loss: 0.0245, D(x): 0.09, D(G(z)): 0.03
# Curr_step [39400/120000], wd_loss: -0.0541, wg_loss: -0.0043, D(x): 0.04, D(G(z)): -0.01
# Curr_step [39600/120000], wd_loss: -0.0572, wg_loss: -0.0178, D(x): 0.05, D(G(z)): -0.01
# Saved generated images..!
# Curr_step [39800/120000], wd_loss: -0.0490, wg_loss: -0.0334, D(x): 0.01, D(G(z)): -0.04
# Curr_step [40000/120000], wd_loss: -0.0663, wg_loss: 0.0088, D(x): 0.08, D(G(z)): 0.01
# Curr_step [40200/120000], wd_loss: -0.0547, wg_loss: -0.0492, D(x): 0.02, D(G(z)): -0.03
# Saved generated images..!
# Curr_step [40400/120000], wd_loss: -0.0512, wg_loss: -0.0324, D(x): 0.02, D(G(z)): -0.03
# Curr_step [40600/120000], wd_loss: -0.0619, wg_loss: -0.0636, D(x): 0.01, D(G(z)): -0.05
# Curr_step [40800/120000], wd_loss: -0.0525, wg_loss: 0.0080, D(x): 0.05, D(G(z)): -0.00
# Saved generated images..!
# Curr_step [41000/120000], wd_loss: -0.0536, wg_loss: -0.0481, D(x): 0.01, D(G(z)): -0.04
# Curr_step [41200/120000], wd_loss: -0.0482, wg_loss: -0.0398, D(x): 0.01, D(G(z)): -0.04
# Curr_step [41400/120000], wd_loss: -0.0487, wg_loss: -0.0736, D(x): -0.02, D(G(z)): -0.07
# Saved generated images..!
# Curr_step [41600/120000], wd_loss: -0.0466, wg_loss: -0.0291, D(x): 0.03, D(G(z)): -0.02
# Curr_step [41800/120000], wd_loss: -0.0566, wg_loss: -0.0469, D(x): 0.01, D(G(z)): -0.04
# Curr_step [42000/120000], wd_loss: -0.0645, wg_loss: -0.0479, D(x): 0.01, D(G(z)): -0.05
# Saved generated images..!
# Curr_step [42200/120000], wd_loss: -0.0783, wg_loss: -0.0308, D(x): 0.04, D(G(z)): -0.04
# Curr_step [42400/120000], wd_loss: -0.0496, wg_loss: -0.0709, D(x): -0.02, D(G(z)): -0.06
# Curr_step [42600/120000], wd_loss: -0.0460, wg_loss: -0.0425, D(x): -0.01, D(G(z)): -0.05
# Saved generated images..!
# Curr_step [42800/120000], wd_loss: -0.0524, wg_loss: -0.0620, D(x): -0.00, D(G(z)): -0.05
# Curr_step [43000/120000], wd_loss: -0.0522, wg_loss: -0.0472, D(x): -0.01, D(G(z)): -0.07
# Curr_step [43200/120000], wd_loss: -0.0484, wg_loss: -0.0964, D(x): -0.04, D(G(z)): -0.09
# Saved generated images..!
# Curr_step [43400/120000], wd_loss: -0.0544, wg_loss: -0.0276, D(x): 0.01, D(G(z)): -0.05
# Curr_step [43600/120000], wd_loss: -0.0563, wg_loss: -0.0545, D(x): 0.00, D(G(z)): -0.05
# Curr_step [43800/120000], wd_loss: -0.0470, wg_loss: -0.0469, D(x): 0.01, D(G(z)): -0.04
# Saved generated images..!
# Curr_step [44000/120000], wd_loss: -0.0529, wg_loss: -0.0356, D(x): 0.02, D(G(z)): -0.03
# Curr_step [44200/120000], wd_loss: -0.0525, wg_loss: -0.0471, D(x): 0.01, D(G(z)): -0.04
# Curr_step [44400/120000], wd_loss: -0.0533, wg_loss: -0.0553, D(x): 0.01, D(G(z)): -0.04
# Saved generated images..!
# Curr_step [44600/120000], wd_loss: -0.0623, wg_loss: -0.0365, D(x): 0.00, D(G(z)): -0.06
# Curr_step [44800/120000], wd_loss: -0.0446, wg_loss: -0.0383, D(x): 0.03, D(G(z)): -0.01
# Curr_step [45000/120000], wd_loss: -0.0582, wg_loss: -0.0453, D(x): 0.02, D(G(z)): -0.04
# Saved generated images..!
# Curr_step [45200/120000], wd_loss: -0.0464, wg_loss: -0.0461, D(x): 0.02, D(G(z)): -0.03
# Curr_step [45400/120000], wd_loss: -0.0440, wg_loss: -0.0617, D(x): -0.02, D(G(z)): -0.07
# Curr_step [45600/120000], wd_loss: -0.0468, wg_loss: -0.0597, D(x): -0.01, D(G(z)): -0.05
# Saved generated images..!
# Curr_step [45800/120000], wd_loss: -0.0483, wg_loss: -0.0203, D(x): 0.02, D(G(z)): -0.03
# Curr_step [46000/120000], wd_loss: -0.0406, wg_loss: -0.0644, D(x): -0.02, D(G(z)): -0.06
# Curr_step [46200/120000], wd_loss: -0.0514, wg_loss: -0.0305, D(x): 0.04, D(G(z)): -0.01
# Saved generated images..!
# Curr_step [46400/120000], wd_loss: -0.0454, wg_loss: -0.0174, D(x): 0.05, D(G(z)): 0.00
# Curr_step [46600/120000], wd_loss: -0.0526, wg_loss: -0.0433, D(x): 0.02, D(G(z)): -0.03
# Curr_step [46800/120000], wd_loss: -0.0433, wg_loss: -0.0250, D(x): 0.02, D(G(z)): -0.02
# Saved generated images..!
# Curr_step [47000/120000], wd_loss: -0.0618, wg_loss: -0.0085, D(x): 0.06, D(G(z)): -0.00
# Curr_step [47200/120000], wd_loss: -0.0483, wg_loss: -0.0771, D(x): -0.04, D(G(z)): -0.08
# Curr_step [47400/120000], wd_loss: -0.0364, wg_loss: -0.0130, D(x): 0.05, D(G(z)): 0.02
# Saved generated images..!
# Curr_step [47600/120000], wd_loss: -0.0606, wg_loss: -0.0323, D(x): 0.03, D(G(z)): -0.03
# Curr_step [47800/120000], wd_loss: -0.0478, wg_loss: -0.0216, D(x): 0.02, D(G(z)): -0.02
# Curr_step [48000/120000], wd_loss: -0.0587, wg_loss: -0.0440, D(x): 0.02, D(G(z)): -0.04
# Saved generated images..!
# Curr_step [48200/120000], wd_loss: -0.0372, wg_loss: -0.0125, D(x): 0.03, D(G(z)): -0.00
# Curr_step [48400/120000], wd_loss: -0.0499, wg_loss: 0.0015, D(x): 0.03, D(G(z)): -0.02
# Curr_step [48600/120000], wd_loss: -0.0514, wg_loss: 0.0109, D(x): 0.05, D(G(z)): -0.00
# Saved generated images..!
# Curr_step [48800/120000], wd_loss: -0.0411, wg_loss: -0.0560, D(x): -0.02, D(G(z)): -0.06
# Curr_step [49000/120000], wd_loss: -0.0506, wg_loss: -0.0238, D(x): 0.02, D(G(z)): -0.03
# Curr_step [49200/120000], wd_loss: -0.0509, wg_loss: -0.0196, D(x): 0.05, D(G(z)): -0.00
# Saved generated images..!
# Curr_step [49400/120000], wd_loss: -0.0465, wg_loss: -0.0356, D(x): 0.02, D(G(z)): -0.02
# Curr_step [49600/120000], wd_loss: -0.0454, wg_loss: -0.0621, D(x): -0.02, D(G(z)): -0.06
# Curr_step [49800/120000], wd_loss: -0.0465, wg_loss: -0.0373, D(x): -0.00, D(G(z)): -0.05
# Saved generated images..!
# Curr_step [50000/120000], wd_loss: -0.0443, wg_loss: 0.0516, D(x): 0.09, D(G(z)): 0.04
# Curr_step [50200/120000], wd_loss: -0.0401, wg_loss: 0.0071, D(x): 0.03, D(G(z)): -0.01
# Curr_step [50400/120000], wd_loss: -0.0485, wg_loss: 0.0063, D(x): 0.05, D(G(z)): -0.00
# Saved generated images..!
# Curr_step [50600/120000], wd_loss: -0.0464, wg_loss: -0.0286, D(x): 0.00, D(G(z)): -0.04
# Curr_step [50800/120000], wd_loss: -0.0482, wg_loss: -0.0437, D(x): 0.01, D(G(z)): -0.04
# Curr_step [51000/120000], wd_loss: -0.0355, wg_loss: -0.0322, D(x): -0.01, D(G(z)): -0.04
# Saved generated images..!
# Curr_step [51200/120000], wd_loss: -0.0470, wg_loss: -0.0409, D(x): 0.02, D(G(z)): -0.02
# Curr_step [51400/120000], wd_loss: -0.0429, wg_loss: -0.0500, D(x): -0.02, D(G(z)): -0.06
# Curr_step [51600/120000], wd_loss: -0.0572, wg_loss: -0.0445, D(x): 0.02, D(G(z)): -0.04
# Saved generated images..!
# Curr_step [51800/120000], wd_loss: -0.0405, wg_loss: -0.0303, D(x): 0.01, D(G(z)): -0.03
# Curr_step [52000/120000], wd_loss: -0.0407, wg_loss: -0.0539, D(x): -0.01, D(G(z)): -0.06
# Curr_step [52200/120000], wd_loss: -0.0500, wg_loss: -0.0131, D(x): 0.05, D(G(z)): -0.00
# Saved generated images..!
# Curr_step [52400/120000], wd_loss: -0.0365, wg_loss: -0.0355, D(x): 0.01, D(G(z)): -0.02
# Curr_step [52600/120000], wd_loss: -0.0385, wg_loss: -0.0806, D(x): -0.05, D(G(z)): -0.09
# Curr_step [52800/120000], wd_loss: -0.0501, wg_loss: 0.0133, D(x): 0.05, D(G(z)): -0.00
# Saved generated images..!
# Curr_step [53000/120000], wd_loss: -0.0505, wg_loss: -0.0157, D(x): 0.05, D(G(z)): -0.00
# Curr_step [53200/120000], wd_loss: -0.0491, wg_loss: 0.0155, D(x): 0.05, D(G(z)): 0.00
# Curr_step [53400/120000], wd_loss: -0.0326, wg_loss: 0.0094, D(x): 0.06, D(G(z)): 0.02
# Saved generated images..!
# Curr_step [53600/120000], wd_loss: -0.0385, wg_loss: -0.0213, D(x): 0.03, D(G(z)): -0.01
# Curr_step [53800/120000], wd_loss: -0.0407, wg_loss: 0.0094, D(x): 0.05, D(G(z)): 0.01
# Curr_step [54000/120000], wd_loss: -0.0470, wg_loss: -0.0177, D(x): 0.04, D(G(z)): -0.01
# Saved generated images..!
# Curr_step [54200/120000], wd_loss: -0.0520, wg_loss: 0.0235, D(x): 0.07, D(G(z)): 0.01
# Curr_step [54400/120000], wd_loss: -0.0470, wg_loss: 0.0358, D(x): 0.11, D(G(z)): 0.06
# Curr_step [54600/120000], wd_loss: -0.0495, wg_loss: 0.0136, D(x): 0.04, D(G(z)): -0.01
# Saved generated images..!
# Curr_step [54800/120000], wd_loss: -0.0441, wg_loss: 0.0026, D(x): 0.04, D(G(z)): -0.00
# Curr_step [55000/120000], wd_loss: -0.0551, wg_loss: 0.0262, D(x): 0.09, D(G(z)): 0.03
# Curr_step [55200/120000], wd_loss: -0.0579, wg_loss: -0.0218, D(x): 0.04, D(G(z)): -0.02
# Saved generated images..!
# Curr_step [55400/120000], wd_loss: -0.0483, wg_loss: -0.0028, D(x): 0.04, D(G(z)): -0.01
# Curr_step [55600/120000], wd_loss: -0.0400, wg_loss: 0.0053, D(x): 0.04, D(G(z)): -0.00
# Curr_step [55800/120000], wd_loss: -0.0458, wg_loss: -0.0155, D(x): 0.01, D(G(z)): -0.04
# Saved generated images..!
# Curr_step [56000/120000], wd_loss: -0.0579, wg_loss: -0.0188, D(x): 0.04, D(G(z)): -0.02
# Curr_step [56200/120000], wd_loss: -0.0360, wg_loss: 0.0101, D(x): 0.04, D(G(z)): 0.00
# Curr_step [56400/120000], wd_loss: -0.0442, wg_loss: 0.0225, D(x): 0.05, D(G(z)): 0.01
# Saved generated images..!
# Curr_step [56600/120000], wd_loss: -0.0422, wg_loss: -0.0167, D(x): 0.02, D(G(z)): -0.02
# Curr_step [56800/120000], wd_loss: -0.0407, wg_loss: 0.0290, D(x): 0.08, D(G(z)): 0.04
# Curr_step [57000/120000], wd_loss: -0.0497, wg_loss: -0.0270, D(x): 0.03, D(G(z)): -0.02
# Saved generated images..!
# Curr_step [57200/120000], wd_loss: -0.0444, wg_loss: 0.0263, D(x): 0.05, D(G(z)): 0.01
# Curr_step [57400/120000], wd_loss: -0.0400, wg_loss: 0.0306, D(x): 0.07, D(G(z)): 0.03
# Curr_step [57600/120000], wd_loss: -0.0430, wg_loss: 0.0187, D(x): 0.07, D(G(z)): 0.03
# Saved generated images..!
# Curr_step [57800/120000], wd_loss: -0.0405, wg_loss: 0.0107, D(x): 0.05, D(G(z)): 0.01
# Curr_step [58000/120000], wd_loss: -0.0431, wg_loss: -0.0138, D(x): 0.01, D(G(z)): -0.03
# Curr_step [58200/120000], wd_loss: -0.0435, wg_loss: 0.0364, D(x): 0.09, D(G(z)): 0.05
# Saved generated images..!
# Curr_step [58400/120000], wd_loss: -0.0435, wg_loss: -0.0096, D(x): 0.04, D(G(z)): -0.00
# Curr_step [58600/120000], wd_loss: -0.0381, wg_loss: 0.0042, D(x): 0.04, D(G(z)): 0.00
# Curr_step [58800/120000], wd_loss: -0.0362, wg_loss: 0.0092, D(x): 0.05, D(G(z)): 0.01
# Saved generated images..!
# Curr_step [59000/120000], wd_loss: -0.0457, wg_loss: 0.0097, D(x): 0.05, D(G(z)): 0.01
# Curr_step [59200/120000], wd_loss: -0.0580, wg_loss: -0.0079, D(x): 0.04, D(G(z)): -0.02
# Curr_step [59400/120000], wd_loss: -0.0310, wg_loss: 0.0195, D(x): 0.07, D(G(z)): 0.04
# Saved generated images..!
# Curr_step [59600/120000], wd_loss: -0.0432, wg_loss: 0.0564, D(x): 0.11, D(G(z)): 0.07
# Curr_step [59800/120000], wd_loss: -0.0317, wg_loss: 0.0047, D(x): 0.04, D(G(z)): 0.01
# Curr_step [60000/120000], wd_loss: -0.0356, wg_loss: 0.0481, D(x): 0.10, D(G(z)): 0.07
# Saved generated images..!
# Curr_step [60200/120000], wd_loss: -0.0428, wg_loss: 0.0285, D(x): 0.08, D(G(z)): 0.04
# Curr_step [60400/120000], wd_loss: -0.0476, wg_loss: 0.0214, D(x): 0.07, D(G(z)): 0.02
# Curr_step [60600/120000], wd_loss: -0.0239, wg_loss: 0.1117, D(x): 0.16, D(G(z)): 0.14
# Saved generated images..!
# Curr_step [60800/120000], wd_loss: -0.0383, wg_loss: 0.0440, D(x): 0.09, D(G(z)): 0.05
# Curr_step [61000/120000], wd_loss: -0.0472, wg_loss: 0.0784, D(x): 0.11, D(G(z)): 0.06
# Curr_step [61200/120000], wd_loss: -0.0359, wg_loss: 0.1273, D(x): 0.15, D(G(z)): 0.12
# Saved generated images..!
# Curr_step [61400/120000], wd_loss: -0.0502, wg_loss: 0.0775, D(x): 0.11, D(G(z)): 0.06
# Curr_step [61600/120000], wd_loss: -0.0338, wg_loss: 0.0178, D(x): 0.07, D(G(z)): 0.04
# Curr_step [61800/120000], wd_loss: -0.0351, wg_loss: 0.0057, D(x): 0.06, D(G(z)): 0.02
# Saved generated images..!
# Curr_step [62000/120000], wd_loss: -0.0340, wg_loss: 0.0644, D(x): 0.12, D(G(z)): 0.08
# Curr_step [62200/120000], wd_loss: -0.0408, wg_loss: 0.0587, D(x): 0.10, D(G(z)): 0.06
# Curr_step [62400/120000], wd_loss: -0.0458, wg_loss: 0.0606, D(x): 0.12, D(G(z)): 0.07
# Saved generated images..!
# Curr_step [62600/120000], wd_loss: -0.0527, wg_loss: 0.0223, D(x): 0.09, D(G(z)): 0.04
# Curr_step [62800/120000], wd_loss: -0.0445, wg_loss: 0.0902, D(x): 0.13, D(G(z)): 0.08
# Curr_step [63000/120000], wd_loss: -0.0446, wg_loss: 0.0660, D(x): 0.11, D(G(z)): 0.07
# Saved generated images..!
# Curr_step [63200/120000], wd_loss: -0.0415, wg_loss: 0.1031, D(x): 0.14, D(G(z)): 0.10
# Curr_step [63400/120000], wd_loss: -0.0341, wg_loss: 0.0839, D(x): 0.15, D(G(z)): 0.12
# Curr_step [63600/120000], wd_loss: -0.0284, wg_loss: 0.0780, D(x): 0.12, D(G(z)): 0.09
# Saved generated images..!
# Curr_step [63800/120000], wd_loss: -0.0453, wg_loss: 0.0768, D(x): 0.12, D(G(z)): 0.07
# Curr_step [64000/120000], wd_loss: -0.0390, wg_loss: 0.1233, D(x): 0.17, D(G(z)): 0.13
# Curr_step [64200/120000], wd_loss: -0.0232, wg_loss: 0.0827, D(x): 0.11, D(G(z)): 0.09
# Saved generated images..!
# Curr_step [64400/120000], wd_loss: -0.0384, wg_loss: 0.0658, D(x): 0.12, D(G(z)): 0.08
# Curr_step [64600/120000], wd_loss: -0.0342, wg_loss: 0.1217, D(x): 0.16, D(G(z)): 0.13
# Curr_step [64800/120000], wd_loss: -0.0298, wg_loss: 0.1385, D(x): 0.17, D(G(z)): 0.14
# Saved generated images..!
# Curr_step [65000/120000], wd_loss: -0.0323, wg_loss: 0.1366, D(x): 0.15, D(G(z)): 0.12
# Curr_step [65200/120000], wd_loss: -0.0315, wg_loss: 0.0889, D(x): 0.11, D(G(z)): 0.07
# Curr_step [65400/120000], wd_loss: -0.0429, wg_loss: 0.1049, D(x): 0.15, D(G(z)): 0.10
# Saved generated images..!
# Curr_step [65600/120000], wd_loss: -0.0417, wg_loss: 0.1062, D(x): 0.14, D(G(z)): 0.10
# Curr_step [65800/120000], wd_loss: -0.0424, wg_loss: 0.0901, D(x): 0.13, D(G(z)): 0.09
# Curr_step [66000/120000], wd_loss: -0.0437, wg_loss: 0.0844, D(x): 0.13, D(G(z)): 0.09
# Saved generated images..!
# Curr_step [66200/120000], wd_loss: -0.0412, wg_loss: 0.1208, D(x): 0.16, D(G(z)): 0.12
# Curr_step [66400/120000], wd_loss: -0.0324, wg_loss: 0.0507, D(x): 0.09, D(G(z)): 0.06
# Curr_step [66600/120000], wd_loss: -0.0416, wg_loss: 0.1125, D(x): 0.16, D(G(z)): 0.12
# Saved generated images..!
# Curr_step [66800/120000], wd_loss: -0.0383, wg_loss: 0.1325, D(x): 0.17, D(G(z)): 0.13
# Curr_step [67000/120000], wd_loss: -0.0448, wg_loss: 0.1456, D(x): 0.18, D(G(z)): 0.13
# Curr_step [67200/120000], wd_loss: -0.0358, wg_loss: 0.1223, D(x): 0.15, D(G(z)): 0.12
# Saved generated images..!
# Curr_step [67400/120000], wd_loss: -0.0332, wg_loss: 0.0954, D(x): 0.13, D(G(z)): 0.09
# Curr_step [67600/120000], wd_loss: -0.0302, wg_loss: 0.1140, D(x): 0.15, D(G(z)): 0.12
# Curr_step [67800/120000], wd_loss: -0.0394, wg_loss: 0.1213, D(x): 0.15, D(G(z)): 0.11
# Saved generated images..!
# Curr_step [68000/120000], wd_loss: -0.0338, wg_loss: 0.1129, D(x): 0.13, D(G(z)): 0.10
# Curr_step [68200/120000], wd_loss: -0.0429, wg_loss: 0.0970, D(x): 0.14, D(G(z)): 0.10
# Curr_step [68400/120000], wd_loss: -0.0300, wg_loss: 0.1150, D(x): 0.14, D(G(z)): 0.11
# Saved generated images..!
# Curr_step [68600/120000], wd_loss: -0.0482, wg_loss: 0.0728, D(x): 0.11, D(G(z)): 0.06
# Curr_step [68800/120000], wd_loss: -0.0327, wg_loss: 0.1120, D(x): 0.13, D(G(z)): 0.10
# Curr_step [69000/120000], wd_loss: -0.0479, wg_loss: 0.1131, D(x): 0.16, D(G(z)): 0.11
# Saved generated images..!
# Curr_step [69200/120000], wd_loss: -0.0367, wg_loss: 0.1043, D(x): 0.16, D(G(z)): 0.12
# Curr_step [69400/120000], wd_loss: -0.0419, wg_loss: 0.1328, D(x): 0.17, D(G(z)): 0.12
# Curr_step [69600/120000], wd_loss: -0.0303, wg_loss: 0.0764, D(x): 0.11, D(G(z)): 0.08
# Saved generated images..!
# Curr_step [69800/120000], wd_loss: -0.0346, wg_loss: 0.1053, D(x): 0.14, D(G(z)): 0.10
# Curr_step [70000/120000], wd_loss: -0.0328, wg_loss: 0.1121, D(x): 0.15, D(G(z)): 0.11
# Curr_step [70200/120000], wd_loss: -0.0343, wg_loss: 0.1359, D(x): 0.18, D(G(z)): 0.14
# Saved generated images..!
# Curr_step [70400/120000], wd_loss: -0.0318, wg_loss: 0.1308, D(x): 0.17, D(G(z)): 0.14
# Curr_step [70600/120000], wd_loss: -0.0296, wg_loss: 0.1181, D(x): 0.15, D(G(z)): 0.12
# Curr_step [70800/120000], wd_loss: -0.0382, wg_loss: 0.1378, D(x): 0.17, D(G(z)): 0.13
# Saved generated images..!
# Curr_step [71000/120000], wd_loss: -0.0297, wg_loss: 0.1570, D(x): 0.20, D(G(z)): 0.17
# Curr_step [71200/120000], wd_loss: -0.0350, wg_loss: 0.1212, D(x): 0.16, D(G(z)): 0.12
# Curr_step [71400/120000], wd_loss: -0.0464, wg_loss: 0.0832, D(x): 0.14, D(G(z)): 0.09
# Saved generated images..!
# Curr_step [71600/120000], wd_loss: -0.0361, wg_loss: 0.0936, D(x): 0.13, D(G(z)): 0.10
# Curr_step [71800/120000], wd_loss: -0.0257, wg_loss: 0.1002, D(x): 0.14, D(G(z)): 0.11
# Curr_step [72000/120000], wd_loss: -0.0223, wg_loss: 0.0833, D(x): 0.13, D(G(z)): 0.10
# Saved generated images..!
# Curr_step [72200/120000], wd_loss: -0.0355, wg_loss: 0.1001, D(x): 0.14, D(G(z)): 0.10
# Curr_step [72400/120000], wd_loss: -0.0335, wg_loss: 0.1032, D(x): 0.13, D(G(z)): 0.10
# Curr_step [72600/120000], wd_loss: -0.0407, wg_loss: 0.0948, D(x): 0.12, D(G(z)): 0.08
# Saved generated images..!
